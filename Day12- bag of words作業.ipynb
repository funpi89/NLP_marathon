# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
# nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n += 1

# %%
word_index
# Out:
# {'up': 0,
#  'massive': 1,
#  'downright': 2,
#  'Eclectic': 3,
#  'stretch': 4,
#  'Phoenix': 5,
#  'happy': 6,
#  'others': 7,
#  'Bacon': 8,
#  'know': 9,
#  'box': 10,
#  'perfect': 11,
#  'Kabuki': 12,
#  'fare': 13,
#  'enough': 14,
#  'below': 15,
#  'flavorful': 16,
#  'course': 17,
#  '3/4ths': 18,
#  'today': 19,
#  'fairly': 20,
#  'auju': 21,
#  'fast': 22,
#  'working/eating': 23,
#  'boys': 24,
#  'succulent': 25,
#  'reminded': 26,
#  'Nothing': 27,
#  'kids': 28,
#  'tailored': 29,
#  'grill': 30,
#  'traditional': 31,
#  'dirt': 32,
#  'Hard': 33,
#  'strawberry': 34,
#  'dollars': 35,
#  'Cod': 36,
#  'ball': 37,
#  'over-priced': 38,
#  'Disappointing': 39,
#  "'": 40,
#  'PEOPLE': 41,
#  'it': 42,
#  'ala': 43,
#  'certainly': 44,
#  'callings': 45,
#  'recently': 46,
#  'dreamed': 47,
#  'revisiting': 48,
#  'nicest': 49,
#  'salmon': 50,
#  'Stopped': 51,
#  'Company': 52,
#  'dedicated': 53,
#  'HAPPENED': 54,
#  'medium': 55,
#  'my': 56,
#  'wash': 57,
#  'waste': 58,
#  'strangers': 59,
#  'atmosphere': 60,
#  'unless': 61,
#  '20': 62,
#  'multi-grain': 63,
#  'bathroom': 64,
#  'upgrading': 65,
#  'minutes': 66,
#  'menu': 67,
#  'ache': 68,
#  'How': 69,
#  'homemade': 70,
#  'thrilled': 71,
#  'third': 72,
#  'left': 73,
#  'Good': 74,
#  'bamboo': 75,
#  'long': 76,
#  'Dessert': 77,
#  'surprised': 78,
#  'crust': 79,
#  'godfathers': 80,
#  'bathrooms': 81,
#  'Yeah': 82,
#  'hooked': 83,
#  'Blah': 84,
#  'Must': 85,
#  'TIME': 86,
#  'crazy': 87,
#  'combo': 88,
#  'remember': 89,
#  'incredibly': 90,
#  'Chipotle': 91,
#  'hamburger': 92,
#  'awkwardly': 93,
#  'middle': 94,
#  'hopes': 95,
#  'family': 96,
#  'market': 97,
#  'club': 98,
#  'Seriously': 99,
#  'obviously': 100,
#  'airline': 101,
#  'looks': 102,
#  'waiting': 103,
#  'extremely': 104,
#  'Baba': 105,
#  'Waiter': 106,
#  'Overall': 107,
#  'seasoned': 108,
#  'prepare': 109,
#  'in': 110,
#  'Sour': 111,
#  'tongue': 112,
#  'unbelievably': 113,
#  'nasty': 114,
#  'AN': 115,
#  'stuff': 116,
#  'Pricing': 117,
#  'The': 118,
#  'Waited': 119,
#  'buffets': 120,
#  'a': 121,
#  'Reasonably': 122,
#  'vomited': 123,
#  'pulled': 124,
#  'If': 125,
#  'Gold': 126,
#  'star': 127,
#  'creamy': 128,
#  'hearts': 129,
#  'those': 130,
#  'sexy': 131,
#  'Bay': 132,
#  "'ll": 133,
#  'Service': 134,
#  'untoasted': 135,
#  'Panna': 136,
#  'number': 137,
#  'disgust': 138,
#  'during': 139,
#  'guys': 140,
#  'smoothies': 141,
#  'coming': 142,
#  'plastic': 143,
#  'falling': 144,
#  'Try': 145,
#  'bother': 146,
#  'lawyers': 147,
#  'smeared': 148,
#  'cooked': 149,
#  'etc': 150,
#  'went': 151,
#  'Third': 152,
#  'food/service': 153,
#  'carbs': 154,
#  'teamwork': 155,
#  'his': 156,
#  'THE': 157,
#  'sals': 158,
#  'gloves.Everything': 159,
#  'Carly': 160,
#  'yum': 161,
#  'frozen': 162,
#  'hello': 163,
#  'Each': 164,
#  'orders': 165,
#  'Perfect': 166,
#  'took': 167,
#  'turkey': 168,
#  'go': 169,
#  'fill': 170,
#  ',': 171,
#  'you': 172,
#  'MUST': 173,
#  'regularly': 174,
#  'douchey': 175,
#  'ourselves': 176,
#  'bellies': 177,
#  'bartender': 178,
#  'recall': 179,
#  'hands-down': 180,
#  'Same': 181,
#  'accommodations': 182,
#  'quality': 183,
#  'cannoli': 184,
#  'brisket': 185,
#  'particular': 186,
#  '11.99': 187,
#  'tasty': 188,
#  'golden-crispy': 189,
#  'mean': 190,
#  'Shrimp-': 191,
#  'anyone': 192,
#  'lacking': 193,
#  'Madison': 194,
#  'angry': 195,
#  'yellowtail': 196,
#  'seen': 197,
#  'blue': 198,
#  'HOUR': 199,
#  'words': 200,
#  'pretty': 201,
#  'getting': 202,
#  'ravoli': 203,
#  'wrap': 204,
#  'sushi': 205,
#  'describing': 206,
#  'believe': 207,
#  'hour': 208,
#  'One': 209,
#  'dressed': 210,
#  'worst': 211,
#  'version': 212,
#  'choose': 213,
#  'olives': 214,
#  'comfortable': 215,
#  'handed': 216,
#  'tapas': 217,
#  'quantity': 218,
#  'petrified': 219,
#  'Voodoo': 220,
#  'consider': 221,
#  'May': 222,
#  'stay': 223,
#  'shots': 224,
#  'STEP': 225,
#  'desserts': 226,
#  'Coming': 227,
#  'scene': 228,
#  'butter': 229,
#  'establishment': 230,
#  'flavors': 231,
#  'missing': 232,
#  'dirty': 233,
#  'Grill': 234,
#  'night': 235,
#  '1': 236,
#  'rave': 237,
#  'nay': 238,
#  'register': 239,
#  'single': 240,
#  'greens': 241,
#  'Kind': 242,
#  'contain': 243,
#  'than': 244,
#  'ratio': 245,
#  'venue': 246,
#  'rushed': 247,
#  'never': 248,
#  'Steak': 249,
#  'lover': 250,
#  'oh': 251,
#  'done': 252,
#  'coconut': 253,
#  'disbelief': 254,
#  'Jenni': 255,
#  'connoisseur': 256,
#  'while': 257,
#  'ahead': 258,
#  'love': 259,
#  'Would': 260,
#  'well': 261,
#  'company': 262,
#  'inviting': 263,
#  'chicken': 264,
#  'Maybe': 265,
#  'filling': 266,
#  'anything': 267,
#  'wait': 268,
#  'Mango': 269,
#  'Although': 270,
#  'Halibut': 271,
#  'cream': 272,
#  'high': 273,
#  'puree': 274,
#  'husband': 275,
#  'patty': 276,
#  'each': 277,
#  'seated': 278,
#  'Scottsdale': 279,
#  'cold': 280,
#  'told': 281,
#  'voted': 282,
#  'Sadly': 283,
#  'pop': 284,
#  'eel': 285,
#  'tuna': 286,
#  'fav': 287,
#  'email': 288,
#  'GC': 289,
#  'holiday': 290,
#  'music': 291,
#  'said': 292,
#  'dates': 293,
#  'attitudes': 294,
#  '6': 295,
#  'sample': 296,
#  'legit': 297,
#  'tried': 298,
#  'eyes': 299,
#  'talking': 300,
#  'same': 301,
#  'Awesome': 302,
#  'fella': 303,
#  'Check': 304,
#  'Pita': 305,
#  'bloodiest': 306,
#  'pan': 307,
#  'M': 308,
#  'Burger': 309,
#  'dine': 310,
#  'chai': 311,
#  'into': 312,
#  'Luke': 313,
#  '%': 314,
#  'pack': 315,
#  'fail': 316,
#  'fact': 317,
#  'disrespected': 318,
#  'Extremely': 319,
#  'Crystals': 320,
#  'guest': 321,
#  'Stars': 322,
#  'providing': 323,
#  'appetizer': 324,
#  'hospitality': 325,
#  'Francisco': 326,
#  'spaghetti': 327,
#  'thats': 328,
#  'Ninja': 329,
#  'five': 330,
#  'disaster': 331,
#  'relax': 332,
#  'pita': 333,
#  'gyro': 334,
#  'pleasure': 335,
#  'drink': 336,
#  'Gyros': 337,
#  'GO': 338,
#  'MANY': 339,
#  'only': 340,
#  'ignore': 341,
#  'might': 342,
#  'avocado': 343,
#  'greatest': 344,
#  'crowds': 345,
#  'workers': 346,
#  'finish': 347,
#  'another': 348,
#  'decor': 349,
#  'totally': 350,
#  'prefer': 351,
#  'helpful': 352,
#  'Paying': 353,
#  'Left': 354,
#  'raving': 355,
#  'rowdy': 356,
#  'wrong': 357,
#  'TOLD': 358,
#  'half': 359,
#  'little': 360,
#  'wrapped': 361,
#  'salsa': 362,
#  'awesome': 363,
#  'nothing': 364,
#  'them': 365,
#  'eggs': 366,
#  'sense': 367,
#  'was': 368,
#  'full': 369,
#  'platter': 370,
#  'tummy': 371,
#  'Definitely': 372,
#  'Han': 373,
#  "'m": 374,
#  'under-services': 375,
#  'elsewhere': 376,
#  'Yama': 377,
#  'part': 378,
#  'Honestly': 379,
#  'Talk': 380,
#  'spicy': 381,
#  'strings': 382,
#  'disappointing': 383,
#  'impressed': 384,
#  'Perhaps': 385,
#  'impressive': 386,
#  'signs': 387,
#  'mind': 388,
#  'hated': 389,
#  'Mmmm': 390,
#  'ranch': 391,
#  'WAAAAAAyyyyyyyyyy': 392,
#  'asking': 393,
#  'who': 394,
#  'anticipated': 395,
#  'informative': 396,
#  'pleasant': 397,
#  'letting': 398,
#  'fabulous': 399,
#  'cow': 400,
#  'yummy': 401,
#  'allergy': 402,
#  'people': 403,
#  'Yelpers': 404,
#  'expectations': 405,
#  'average': 406,
#  'Food': 407,
#  'lettuce': 408,
#  'damn': 409,
#  'gold': 410,
#  'Back': 411,
#  'tastings': 412,
#  'Also': 413,
#  'buying': 414,
#  'tepid': 415,
#  'friends': 416,
#  'non-fancy': 417,
#  'brought': 418,
#  'checked': 419,
#  'boring': 420,
#  'imagine': 421,
#  'AVOID': 422,
#  'served': 423,
#  'wayyy': 424,
#  'loudly': 425,
#  'boiled': 426,
#  'disgusting': 427,
#  'imagined': 428,
#  'multiple': 429,
#  'topic': 430,
#  '....': 431,
#  'get': 432,
#  'being': 433,
#  'with': 434,
#  'tough': 435,
#  'favor': 436,
#  'AZ': 437,
#  'Hunan': 438,
#  'dime': 439,
#  'boxes': 440,
#  'anytime': 441,
#  'rather': 442,
#  'steaks': 443,
#  'Similarly': 444,
#  'amount': 445,
#  'gooodd': 446,
#  'Christmas': 447,
#  'egg': 448,
#  'fucking': 449,
#  'down': 450,
#  'cute': 451,
#  'enjoyable': 452,
#  'disgusted': 453,
#  'delivery': 454,
#  'brother': 455,
#  'gone': 456,
#  'carpaccio': 457,
#  'amazing': 458,
#  'Veggitarian': 459,
#  'place': 460,
#  'between': 461,
#  'Much': 462,
#  'moist': 463,
#  'Camelback': 464,
#  'Favorite': 465,
#  'disgraceful': 466,
#  'large': 467,
#  'salty': 468,
#  'Give': 469,
#  'whatsoever': 470,
#  'tiramisu': 471,
#  'foot': 472,
#  '``': 473,
#  'legs': 474,
#  'Sushi': 475,
#  'awful': 476,
#  'summary': 477,
#  'paper': 478,
#  'TV': 479,
#  '30': 480,
#  'offers': 481,
#  'eyed': 482,
#  'picture': 483,
#  'all': 484,
#  'yukon': 485,
#  'veal': 486,
#  'return': 487,
#  'because': 488,
#  'trips': 489,
#  'plate': 490,
#  'constructed': 491,
#  'tragedy': 492,
#  'Needless': 493,
#  'tater': 494,
#  'Everything': 495,
#  'boyfriend': 496,
#  'winner': 497,
#  'second': 498,
#  'Def': 499,
#  'meat': 500,
#  'Generous': 501,
#  'folks': 502,
#  '3': 503,
#  'changing': 504,
#  'reason': 505,
#  'cheek': 506,
#  'bartenders': 507,
#  'better': 508,
#  'dining': 509,
#  'toro': 510,
#  'recommend': 511,
#  'effort': 512,
#  'Eve': 513,
#  'Salad': 514,
#  'operation': 515,
#  'simple': 516,
#  'Tasty': 517,
#  'mid': 518,
#  'Pretty': 519,
#  'spotty': 520,
#  'simply': 521,
#  'sure': 522,
#  'Tonight': 523,
#  'ice': 524,
#  'Big': 525,
#  'Friend': 526,
#  'Loved': 527,
#  'close': 528,
#  'Thoroughly': 529,
#  'Have': 530,
#  'fried': 531,
#  'suggest': 532,
#  'front': 533,
#  'thick': 534,
#  'grow': 535,
#  'cocktails': 536,
#  'cheesecurds': 537,
#  'like': 538,
#  'Lemon': 539,
#  'concept': 540,
#  'Come': 541,
#  'batch': 542,
#  'gratitude': 543,
#  'he': 544,
#  'honestly': 545,
#  'wasted': 546,
#  'Be': 547,
#  'subpar': 548,
#  "'s": 549,
#  'basically': 550,
#  'Unfortunately': 551,
#  'talk': 552,
#  'BETTER': 553,
#  'arrives': 554,
#  'noodles': 555,
#  'atrocious': 556,
#  'older': 557,
#  'enjoy': 558,
#  'twice': 559,
#  'array': 560,
#  'relaxed': 561,
#  'visited': 562,
#  'needed': 563,
#  'that': 564,
#  'right': 565,
#  'guests': 566,
#  'Once': 567,
#  'Gringos': 568,
#  'speedy': 569,
#  'employee': 570,
#  'not': 571,
#  'crawfish': 572,
#  'greeted': 573,
#  'readers': 574,
#  'cheeseburger': 575,
#  'given': 576,
#  'Everyone': 577,
#  'let': 578,
#  'jewel': 579,
#  'or': 580,
#  'ones': 581,
#  'pizza': 582,
#  'palate': 583,
#  'STALE': 584,
#  'everything': 585,
#  'colder': 586,
#  'Those': 587,
#  'Filet': 588,
#  'styrofoam': 589,
#  'deliver': 590,
#  'Overpriced': 591,
#  'inspired': 592,
#  "'d": 593,
#  'rotating': 594,
#  'were': 595,
#  'mmmm': 596,
#  'BACK': 597,
#  'located': 598,
#  'struck': 599,
#  'patio': 600,
#  'slaw': 601,
#  'industry': 602,
#  'weekend': 603,
#  'Restaurant': 604,
#  'specials': 605,
#  'great': 606,
#  'they': 607,
#  'Poor': 608,
#  'courteous': 609,
#  'unfortunately': 610,
#  'difference': 611,
#  '17': 612,
#  'rated': 613,
#  'boot': 614,
#  'Ha': 615,
#  'deal': 616,
#  'limited': 617,
#  'street': 618,
#  'via': 619,
#  'hair': 620,
#  'handled': 621,
#  'thing': 622,
#  'pictures': 623,
#  'we': 624,
#  'These': 625,
#  'Very': 626,
#  'Prices': 627,
#  'stood': 628,
#  'Risotto': 629,
#  'Lordy': 630,
#  'to-go': 631,
#  'need': 632,
#  'almost': 633,
#  'similar': 634,
#  'pears': 635,
#  'send': 636,
#  'Why': 637,
#  'selection': 638,
#  'i': 639,
#  'from': 640,
#  'putting': 641,
#  'rarely': 642,
#  'peanut': 643,
#  'All': 644,
#  'dessert': 645,
#  'Vegetarian': 646,
#  "n't": 647,
#  'reheated': 648,
#  'crowd': 649,
#  'joint': 650,
#  'though': 651,
#  'figured': 652,
#  'brunch': 653,
#  'kitchen': 654,
#  'coffee': 655,
#  'coupons': 656,
#  'event': 657,
#  'Join': 658,
#  'baby': 659,
#  'calamari': 660,
#  'Dylan': 661,
#  'Hopefully': 662,
#  'her': 663,
#  'highlighted': 664,
#  'And': 665,
#  'disapppointment': 666,
#  'charcoal': 667,
#  'pleased': 668,
#  'outrageously': 669,
#  '......': 670,
#  'shops': 671,
#  'grilled': 672,
#  'crumby': 673,
#  'DELICIOUS': 674,
#  'wanted': 675,
#  'sunglasses': 676,
#  'wine': 677,
#  'healthy': 678,
#  'problem': 679,
#  'above': 680,
#  'dried': 681,
#  'item': 682,
#  'head': 683,
#  'further': 684,
#  'promise': 685,
#  'It': 686,
#  'excuse': 687,
#  'ways': 688,
#  'peas': 689,
#  'bodes': 690,
#  'fo': 691,
#  'refreshing': 692,
#  'store': 693,
#  'fruit': 694,
#  'Bland': 695,
#  'fine': 696,
#  'southwest': 697,
#  'spot': 698,
#  'kiddos': 699,
#  'Phenomenal': 700,
#  'acknowledged': 701,
#  'business': 702,
#  'REALLY': 703,
#  'recommending': 704,
#  'personable': 705,
#  'Then': 706,
#  'rolled': 707,
#  'Bean': 708,
#  'literally': 709,
#  'mall': 710,
#  'diverse': 711,
#  'smooth': 712,
#  'wedges': 713,
#  'cheated': 714,
#  'Bellagio': 715,
#  'Horrible': 716,
#  '30s': 717,
#  'their': 718,
#  'biscuits': 719,
#  'party': 720,
#  'Im': 721,
#  'waiter': 722,
#  'order': 723,
#  'Italian': 724,
#  'onion': 725,
#  'thinking': 726,
#  'absolutley': 727,
#  'plethora': 728,
#  'forgetting': 729,
#  'myself': 730,
#  'But': 731,
#  'cost': 732,
#  'mesquite': 733,
#  'pay': 734,
#  'tartare': 735,
#  'cake': 736,
#  'Brushfire': 737,
#  'salt': 738,
#  'hits': 739,
#  'needs': 740,
#  'missed': 741,
#  'biggest': 742,
#  'especially': 743,
#  'article': 744,
#  'leaves': 745,
#  'Nobu': 746,
#  'honor': 747,
#  'evening': 748,
#  'RUDE': 749,
#  'shower': 750,
#  'public': 751,
#  'Fridays': 752,
#  'reasonable': 753,
#  '...': 754,
#  'final': 755,
#  'walls': 756,
#  'skimp': 757,
#  'black': 758,
#  'says': 759,
#  'Thumbs': 760,
#  'flavorless': 761,
#  'shopping': 762,
#  'metro': 763,
#  'realized': 764,
#  'trimmed': 765,
#  'patron': 766,
#  'Plus': 767,
#  'chefs': 768,
#  'caught': 769,
#  'across': 770,
#  'claimed': 771,
#  'refused': 772,
#  'solidify': 773,
#  'yourself': 774,
#  'Delight': 775,
#  'Appetite': 776,
#  'NO': 777,
#  'At': 778,
#  'Mom': 779,
#  'Eggplant': 780,
#  'dusted': 781,
#  'as': 782,
#  'HAVE': 783,
#  'seriously': 784,
#  'dirty-': 785,
#  'show': 786,
#  'cramming': 787,
#  'side': 788,
#  'then': 789,
#  'genuinely': 790,
#  'wagyu': 791,
#  'heads': 792,
#  'daily': 793,
#  'pancakes': 794,
#  'requested': 795,
#  'joy': 796,
#  'pumpkin': 797,
#  'AGAIN': 798,
#  'dude': 799,
#  'an': 800,
#  'watered': 801,
#  'NEVER': 802,
#  'reasonably': 803,
#  'avoided': 804,
#  'going': 805,
#  'light': 806,
#  'here': 807,
#  'MANAGEMENT': 808,
#  'expert/connisseur': 809,
#  'used': 810,
#  'portion': 811,
#  'lukewarm': 812,
#  'beyond': 813,
#  'vegan/veggie': 814,
#  'him': 815,
#  'walked': 816,
#  'professional': 817,
#  'sliced': 818,
#  'OK': 819,
#  'They': 820,
#  'without': 821,
#  'unhealthy': 822,
#  'raspberry': 823,
#  'giving': 824,
#  'trippy': 825,
#  'zero': 826,
#  'chocolate': 827,
#  'reservation': 828,
#  'table': 829,
#  'occasions': 830,
#  'Baseball': 831,
#  'IT': 832,
#  'Buldogis': 833,
#  'mistake': 834,
#  'poured': 835,
#  'looked': 836,
#  'proclaimed': 837,
#  'Pros': 838,
#  'sucked': 839,
#  'Plater': 840,
#  'date': 841,
#  'Probably': 842,
#  'mains': 843,
#  'finally': 844,
#  'gratuity': 845,
#  'attentive': 846,
#  'sugar': 847,
#  'contained': 848,
#  'foods': 849,
#  'Strip': 850,
#  'Sprouts': 851,
#  'trying': 852,
#  'easily': 853,
#  'would': 854,
#  'shoots': 855,
#  '90': 856,
#  'TOTAL': 857,
#  'ambiance': 858,
#  'are': 859,
#  'treated': 860,
#  'First': 861,
#  'new': 862,
#  'rare': 863,
#  'fails': 864,
#  'years': 865,
#  'RI': 866,
#  'truly': 867,
#  'received': 868,
#  'unprofessional': 869,
#  'so': 870,
#  'bunch': 871,
#  'groups': 872,
#  'Both': 873,
#  'beauty': 874,
#  'bite': 875,
#  'trip': 876,
#  'larger': 877,
#  'beateous': 878,
#  'red': 879,
#  'Mandalay': 880,
#  'rest': 881,
#  'spring': 882,
#  'Jamaican': 883,
#  'wants': 884,
#  'touched': 885,
#  'extensive': 886,
#  'Soups': 887,
#  'outdoor': 888,
#  'reduction': 889,
#  'Hawaiian': 890,
#  'Casino': 891,
#  'short': 892,
#  'book': 893,
#  'Server': 894,
#  'completely': 895,
#  'Went': 896,
#  'court': 897,
#  'mouth': 898,
#  'cashier': 899,
#  'fresh': 900,
#  'word': 901,
#  'juice': 902,
#  'person': 903,
#  'work': 904,
#  'law': 905,
#  'play': 906,
#  'Shop': 907,
#  'mouthful': 908,
#  'LEGIT': 909,
#  'Now': 910,
#  'rate': 911,
#  'Spend': 912,
#  'grease': 913,
#  'overhaul': 914,
#  'tolerance': 915,
#  'hereas': 916,
#  'Paradise': 917,
#  'devine': 918,
#  'Hiro': 919,
#  'been-stepped-in-and-tracked-everywhere': 920,
#  'saffron': 921,
#  'of': 922,
#  'opened': 923,
#  '1/2': 924,
#  'sorely': 925,
#  'suck': 926,
#  'real': 927,
#  'maybe': 928,
#  'finger': 929,
#  'ground': 930,
#  'banana': 931,
#  'is': 932,
#  'pine': 933,
#  'somewhat': 934,
#  'gyros': 935,
#  'works': 936,
#  'Thai': 937,
#  'hostess': 938,
#  'pastas': 939,
#  'quickly': 940,
#  'Mushroom': 941,
#  'make': 942,
#  'chains': 943,
#  'always': 944,
#  'besides': 945,
#  'thumbs': 946,
#  'modern': 947,
#  'dont': 948,
#  'Gordon': 949,
#  'if': 950,
#  'charming': 951,
#  'Sat': 952,
#  'crisp': 953,
#  'tell': 954,
#  'station': 955,
#  'Buffet': 956,
#  'find': 957,
#  'live': 958,
#  'wasting': 959,
#  'delicate': 960,
#  'cooking': 961,
#  'Hands': 962,
#  'meals': 963,
#  'tea': 964,
#  'Highly': 965,
#  'replenished': 966,
#  'drenched': 967,
#  'but': 968,
#  'stars': 969,
#  'bone': 970,
#  'refill': 971,
#  'refried': 972,
#  'opportunity': 973,
#  'rib': 974,
#  'beautiful': 975,
#  'Tucson': 976,
#  'guess': 977,
#  'Wienerschnitzel': 978,
#  'review': 979,
#  'peach': 980,
#  'peanuts': 981,
#  'serves': 982,
#  'BITCHES': 983,
#  'undercooked': 984,
#  'fell': 985,
#  'inexpensive': 986,
#  'its': 987,
#  'decision': 988,
#  'busy': 989,
#  'disagree': 990,
#  'giant': 991,
#  'garden': 992,
#  "ya'all": 993,
#  'gem': 994,
#  'FREEZING': 995,
#  'descriptions': 996,
#  'Joey': 997,
#  'crêpe': 998,
#  'Elk': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'up',
#  1: 'massive',
#  2: 'downright',
#  3: 'Eclectic',
#  4: 'stretch',
#  5: 'Phoenix',
#  6: 'happy',
#  7: 'others',
#  8: 'Bacon',
#  9: 'know',
#  10: 'box',
#  11: 'perfect',
#  12: 'Kabuki',
#  13: 'fare',
#  14: 'enough',
#  15: 'below',
#  16: 'flavorful',
#  17: 'course',
#  18: '3/4ths',
#  19: 'today',
#  20: 'fairly',
#  21: 'auju',
#  22: 'fast',
#  23: 'working/eating',
#  24: 'boys',
#  25: 'succulent',
#  26: 'reminded',
#  27: 'Nothing',
#  28: 'kids',
#  29: 'tailored',
#  30: 'grill',
#  31: 'traditional',
#  32: 'dirt',
#  33: 'Hard',
#  34: 'strawberry',
#  35: 'dollars',
#  36: 'Cod',
#  37: 'ball',
#  38: 'over-priced',
#  39: 'Disappointing',
#  40: "'",
#  41: 'PEOPLE',
#  42: 'it',
#  43: 'ala',
#  44: 'certainly',
#  45: 'callings',
#  46: 'recently',
#  47: 'dreamed',
#  48: 'revisiting',
#  49: 'nicest',
#  50: 'salmon',
#  51: 'Stopped',
#  52: 'Company',
#  53: 'dedicated',
#  54: 'HAPPENED',
#  55: 'medium',
#  56: 'my',
#  57: 'wash',
#  58: 'waste',
#  59: 'strangers',
#  60: 'atmosphere',
#  61: 'unless',
#  62: '20',
#  63: 'multi-grain',
#  64: 'bathroom',
#  65: 'upgrading',
#  66: 'minutes',
#  67: 'menu',
#  68: 'ache',
#  69: 'How',
#  70: 'homemade',
#  71: 'thrilled',
#  72: 'third',
#  73: 'left',
#  74: 'Good',
#  75: 'bamboo',
#  76: 'long',
#  77: 'Dessert',
#  78: 'surprised',
#  79: 'crust',
#  80: 'godfathers',
#  81: 'bathrooms',
#  82: 'Yeah',
#  83: 'hooked',
#  84: 'Blah',
#  85: 'Must',
#  86: 'TIME',
#  87: 'crazy',
#  88: 'combo',
#  89: 'remember',
#  90: 'incredibly',
#  91: 'Chipotle',
#  92: 'hamburger',
#  93: 'awkwardly',
#  94: 'middle',
#  95: 'hopes',
#  96: 'family',
#  97: 'market',
#  98: 'club',
#  99: 'Seriously',
#  100: 'obviously',
#  101: 'airline',
#  102: 'looks',
#  103: 'waiting',
#  104: 'extremely',
#  105: 'Baba',
#  106: 'Waiter',
#  107: 'Overall',
#  108: 'seasoned',
#  109: 'prepare',
#  110: 'in',
#  111: 'Sour',
#  112: 'tongue',
#  113: 'unbelievably',
#  114: 'nasty',
#  115: 'AN',
#  116: 'stuff',
#  117: 'Pricing',
#  118: 'The',
#  119: 'Waited',
#  120: 'buffets',
#  121: 'a',
#  122: 'Reasonably',
#  123: 'vomited',
#  124: 'pulled',
#  125: 'If',
#  126: 'Gold',
#  127: 'star',
#  128: 'creamy',
#  129: 'hearts',
#  130: 'those',
#  131: 'sexy',
#  132: 'Bay',
#  133: "'ll",
#  134: 'Service',
#  135: 'untoasted',
#  136: 'Panna',
#  137: 'number',
#  138: 'disgust',
#  139: 'during',
#  140: 'guys',
#  141: 'smoothies',
#  142: 'coming',
#  143: 'plastic',
#  144: 'falling',
#  145: 'Try',
#  146: 'bother',
#  147: 'lawyers',
#  148: 'smeared',
#  149: 'cooked',
#  150: 'etc',
#  151: 'went',
#  152: 'Third',
#  153: 'food/service',
#  154: 'carbs',
#  155: 'teamwork',
#  156: 'his',
#  157: 'THE',
#  158: 'sals',
#  159: 'gloves.Everything',
#  160: 'Carly',
#  161: 'yum',
#  162: 'frozen',
#  163: 'hello',
#  164: 'Each',
#  165: 'orders',
#  166: 'Perfect',
#  167: 'took',
#  168: 'turkey',
#  169: 'go',
#  170: 'fill',
#  171: ',',
#  172: 'you',
#  173: 'MUST',
#  174: 'regularly',
#  175: 'douchey',
#  176: 'ourselves',
#  177: 'bellies',
#  178: 'bartender',
#  179: 'recall',
#  180: 'hands-down',
#  181: 'Same',
#  182: 'accommodations',
#  183: 'quality',
#  184: 'cannoli',
#  185: 'brisket',
#  186: 'particular',
#  187: '11.99',
#  188: 'tasty',
#  189: 'golden-crispy',
#  190: 'mean',
#  191: 'Shrimp-',
#  192: 'anyone',
#  193: 'lacking',
#  194: 'Madison',
#  195: 'angry',
#  196: 'yellowtail',
#  197: 'seen',
#  198: 'blue',
#  199: 'HOUR',
#  200: 'words',
#  201: 'pretty',
#  202: 'getting',
#  203: 'ravoli',
#  204: 'wrap',
#  205: 'sushi',
#  206: 'describing',
#  207: 'believe',
#  208: 'hour',
#  209: 'One',
#  210: 'dressed',
#  211: 'worst',
#  212: 'version',
#  213: 'choose',
#  214: 'olives',
#  215: 'comfortable',
#  216: 'handed',
#  217: 'tapas',
#  218: 'quantity',
#  219: 'petrified',
#  220: 'Voodoo',
#  221: 'consider',
#  222: 'May',
#  223: 'stay',
#  224: 'shots',
#  225: 'STEP',
#  226: 'desserts',
#  227: 'Coming',
#  228: 'scene',
#  229: 'butter',
#  230: 'establishment',
#  231: 'flavors',
#  232: 'missing',
#  233: 'dirty',
#  234: 'Grill',
#  235: 'night',
#  236: '1',
#  237: 'rave',
#  238: 'nay',
#  239: 'register',
#  240: 'single',
#  241: 'greens',
#  242: 'Kind',
#  243: 'contain',
#  244: 'than',
#  245: 'ratio',
#  246: 'venue',
#  247: 'rushed',
#  248: 'never',
#  249: 'Steak',
#  250: 'lover',
#  251: 'oh',
#  252: 'done',
#  253: 'coconut',
#  254: 'disbelief',
#  255: 'Jenni',
#  256: 'connoisseur',
#  257: 'while',
#  258: 'ahead',
#  259: 'love',
#  260: 'Would',
#  261: 'well',
#  262: 'company',
#  263: 'inviting',
#  264: 'chicken',
#  265: 'Maybe',
#  266: 'filling',
#  267: 'anything',
#  268: 'wait',
#  269: 'Mango',
#  270: 'Although',
#  271: 'Halibut',
#  272: 'cream',
#  273: 'high',
#  274: 'puree',
#  275: 'husband',
#  276: 'patty',
#  277: 'each',
#  278: 'seated',
#  279: 'Scottsdale',
#  280: 'cold',
#  281: 'told',
#  282: 'voted',
#  283: 'Sadly',
#  284: 'pop',
#  285: 'eel',
#  286: 'tuna',
#  287: 'fav',
#  288: 'email',
#  289: 'GC',
#  290: 'holiday',
#  291: 'music',
#  292: 'said',
#  293: 'dates',
#  294: 'attitudes',
#  295: '6',
#  296: 'sample',
#  297: 'legit',
#  298: 'tried',
#  299: 'eyes',
#  300: 'talking',
#  301: 'same',
#  302: 'Awesome',
#  303: 'fella',
#  304: 'Check',
#  305: 'Pita',
#  306: 'bloodiest',
#  307: 'pan',
#  308: 'M',
#  309: 'Burger',
#  310: 'dine',
#  311: 'chai',
#  312: 'into',
#  313: 'Luke',
#  314: '%',
#  315: 'pack',
#  316: 'fail',
#  317: 'fact',
#  318: 'disrespected',
#  319: 'Extremely',
#  320: 'Crystals',
#  321: 'guest',
#  322: 'Stars',
#  323: 'providing',
#  324: 'appetizer',
#  325: 'hospitality',
#  326: 'Francisco',
#  327: 'spaghetti',
#  328: 'thats',
#  329: 'Ninja',
#  330: 'five',
#  331: 'disaster',
#  332: 'relax',
#  333: 'pita',
#  334: 'gyro',
#  335: 'pleasure',
#  336: 'drink',
#  337: 'Gyros',
#  338: 'GO',
#  339: 'MANY',
#  340: 'only',
#  341: 'ignore',
#  342: 'might',
#  343: 'avocado',
#  344: 'greatest',
#  345: 'crowds',
#  346: 'workers',
#  347: 'finish',
#  348: 'another',
#  349: 'decor',
#  350: 'totally',
#  351: 'prefer',
#  352: 'helpful',
#  353: 'Paying',
#  354: 'Left',
#  355: 'raving',
#  356: 'rowdy',
#  357: 'wrong',
#  358: 'TOLD',
#  359: 'half',
#  360: 'little',
#  361: 'wrapped',
#  362: 'salsa',
#  363: 'awesome',
#  364: 'nothing',
#  365: 'them',
#  366: 'eggs',
#  367: 'sense',
#  368: 'was',
#  369: 'full',
#  370: 'platter',
#  371: 'tummy',
#  372: 'Definitely',
#  373: 'Han',
#  374: "'m",
#  375: 'under-services',
#  376: 'elsewhere',
#  377: 'Yama',
#  378: 'part',
#  379: 'Honestly',
#  380: 'Talk',
#  381: 'spicy',
#  382: 'strings',
#  383: 'disappointing',
#  384: 'impressed',
#  385: 'Perhaps',
#  386: 'impressive',
#  387: 'signs',
#  388: 'mind',
#  389: 'hated',
#  390: 'Mmmm',
#  391: 'ranch',
#  392: 'WAAAAAAyyyyyyyyyy',
#  393: 'asking',
#  394: 'who',
#  395: 'anticipated',
#  396: 'informative',
#  397: 'pleasant',
#  398: 'letting',
#  399: 'fabulous',
#  400: 'cow',
#  401: 'yummy',
#  402: 'allergy',
#  403: 'people',
#  404: 'Yelpers',
#  405: 'expectations',
#  406: 'average',
#  407: 'Food',
#  408: 'lettuce',
#  409: 'damn',
#  410: 'gold',
#  411: 'Back',
#  412: 'tastings',
#  413: 'Also',
#  414: 'buying',
#  415: 'tepid',
#  416: 'friends',
#  417: 'non-fancy',
#  418: 'brought',
#  419: 'checked',
#  420: 'boring',
#  421: 'imagine',
#  422: 'AVOID',
#  423: 'served',
#  424: 'wayyy',
#  425: 'loudly',
#  426: 'boiled',
#  427: 'disgusting',
#  428: 'imagined',
#  429: 'multiple',
#  430: 'topic',
#  431: '....',
#  432: 'get',
#  433: 'being',
#  434: 'with',
#  435: 'tough',
#  436: 'favor',
#  437: 'AZ',
#  438: 'Hunan',
#  439: 'dime',
#  440: 'boxes',
#  441: 'anytime',
#  442: 'rather',
#  443: 'steaks',
#  444: 'Similarly',
#  445: 'amount',
#  446: 'gooodd',
#  447: 'Christmas',
#  448: 'egg',
#  449: 'fucking',
#  450: 'down',
#  451: 'cute',
#  452: 'enjoyable',
#  453: 'disgusted',
#  454: 'delivery',
#  455: 'brother',
#  456: 'gone',
#  457: 'carpaccio',
#  458: 'amazing',
#  459: 'Veggitarian',
#  460: 'place',
#  461: 'between',
#  462: 'Much',
#  463: 'moist',
#  464: 'Camelback',
#  465: 'Favorite',
#  466: 'disgraceful',
#  467: 'large',
#  468: 'salty',
#  469: 'Give',
#  470: 'whatsoever',
#  471: 'tiramisu',
#  472: 'foot',
#  473: '``',
#  474: 'legs',
#  475: 'Sushi',
#  476: 'awful',
#  477: 'summary',
#  478: 'paper',
#  479: 'TV',
#  480: '30',
#  481: 'offers',
#  482: 'eyed',
#  483: 'picture',
#  484: 'all',
#  485: 'yukon',
#  486: 'veal',
#  487: 'return',
#  488: 'because',
#  489: 'trips',
#  490: 'plate',
#  491: 'constructed',
#  492: 'tragedy',
#  493: 'Needless',
#  494: 'tater',
#  495: 'Everything',
#  496: 'boyfriend',
#  497: 'winner',
#  498: 'second',
#  499: 'Def',
#  500: 'meat',
#  501: 'Generous',
#  502: 'folks',
#  503: '3',
#  504: 'changing',
#  505: 'reason',
#  506: 'cheek',
#  507: 'bartenders',
#  508: 'better',
#  509: 'dining',
#  510: 'toro',
#  511: 'recommend',
#  512: 'effort',
#  513: 'Eve',
#  514: 'Salad',
#  515: 'operation',
#  516: 'simple',
#  517: 'Tasty',
#  518: 'mid',
#  519: 'Pretty',
#  520: 'spotty',
#  521: 'simply',
#  522: 'sure',
#  523: 'Tonight',
#  524: 'ice',
#  525: 'Big',
#  526: 'Friend',
#  527: 'Loved',
#  528: 'close',
#  529: 'Thoroughly',
#  530: 'Have',
#  531: 'fried',
#  532: 'suggest',
#  533: 'front',
#  534: 'thick',
#  535: 'grow',
#  536: 'cocktails',
#  537: 'cheesecurds',
#  538: 'like',
#  539: 'Lemon',
#  540: 'concept',
#  541: 'Come',
#  542: 'batch',
#  543: 'gratitude',
#  544: 'he',
#  545: 'honestly',
#  546: 'wasted',
#  547: 'Be',
#  548: 'subpar',
#  549: "'s",
#  550: 'basically',
#  551: 'Unfortunately',
#  552: 'talk',
#  553: 'BETTER',
#  554: 'arrives',
#  555: 'noodles',
#  556: 'atrocious',
#  557: 'older',
#  558: 'enjoy',
#  559: 'twice',
#  560: 'array',
#  561: 'relaxed',
#  562: 'visited',
#  563: 'needed',
#  564: 'that',
#  565: 'right',
#  566: 'guests',
#  567: 'Once',
#  568: 'Gringos',
#  569: 'speedy',
#  570: 'employee',
#  571: 'not',
#  572: 'crawfish',
#  573: 'greeted',
#  574: 'readers',
#  575: 'cheeseburger',
#  576: 'given',
#  577: 'Everyone',
#  578: 'let',
#  579: 'jewel',
#  580: 'or',
#  581: 'ones',
#  582: 'pizza',
#  583: 'palate',
#  584: 'STALE',
#  585: 'everything',
#  586: 'colder',
#  587: 'Those',
#  588: 'Filet',
#  589: 'styrofoam',
#  590: 'deliver',
#  591: 'Overpriced',
#  592: 'inspired',
#  593: "'d",
#  594: 'rotating',
#  595: 'were',
#  596: 'mmmm',
#  597: 'BACK',
#  598: 'located',
#  599: 'struck',
#  600: 'patio',
#  601: 'slaw',
#  602: 'industry',
#  603: 'weekend',
#  604: 'Restaurant',
#  605: 'specials',
#  606: 'great',
#  607: 'they',
#  608: 'Poor',
#  609: 'courteous',
#  610: 'unfortunately',
#  611: 'difference',
#  612: '17',
#  613: 'rated',
#  614: 'boot',
#  615: 'Ha',
#  616: 'deal',
#  617: 'limited',
#  618: 'street',
#  619: 'via',
#  620: 'hair',
#  621: 'handled',
#  622: 'thing',
#  623: 'pictures',
#  624: 'we',
#  625: 'These',
#  626: 'Very',
#  627: 'Prices',
#  628: 'stood',
#  629: 'Risotto',
#  630: 'Lordy',
#  631: 'to-go',
#  632: 'need',
#  633: 'almost',
#  634: 'similar',
#  635: 'pears',
#  636: 'send',
#  637: 'Why',
#  638: 'selection',
#  639: 'i',
#  640: 'from',
#  641: 'putting',
#  642: 'rarely',
#  643: 'peanut',
#  644: 'All',
#  645: 'dessert',
#  646: 'Vegetarian',
#  647: "n't",
#  648: 'reheated',
#  649: 'crowd',
#  650: 'joint',
#  651: 'though',
#  652: 'figured',
#  653: 'brunch',
#  654: 'kitchen',
#  655: 'coffee',
#  656: 'coupons',
#  657: 'event',
#  658: 'Join',
#  659: 'baby',
#  660: 'calamari',
#  661: 'Dylan',
#  662: 'Hopefully',
#  663: 'her',
#  664: 'highlighted',
#  665: 'And',
#  666: 'disapppointment',
#  667: 'charcoal',
#  668: 'pleased',
#  669: 'outrageously',
#  670: '......',
#  671: 'shops',
#  672: 'grilled',
#  673: 'crumby',
#  674: 'DELICIOUS',
#  675: 'wanted',
#  676: 'sunglasses',
#  677: 'wine',
#  678: 'healthy',
#  679: 'problem',
#  680: 'above',
#  681: 'dried',
#  682: 'item',
#  683: 'head',
#  684: 'further',
#  685: 'promise',
#  686: 'It',
#  687: 'excuse',
#  688: 'ways',
#  689: 'peas',
#  690: 'bodes',
#  691: 'fo',
#  692: 'refreshing',
#  693: 'store',
#  694: 'fruit',
#  695: 'Bland',
#  696: 'fine',
#  697: 'southwest',
#  698: 'spot',
#  699: 'kiddos',
#  700: 'Phenomenal',
#  701: 'acknowledged',
#  702: 'business',
#  703: 'REALLY',
#  704: 'recommending',
#  705: 'personable',
#  706: 'Then',
#  707: 'rolled',
#  708: 'Bean',
#  709: 'literally',
#  710: 'mall',
#  711: 'diverse',
#  712: 'smooth',
#  713: 'wedges',
#  714: 'cheated',
#  715: 'Bellagio',
#  716: 'Horrible',
#  717: '30s',
#  718: 'their',
#  719: 'biscuits',
#  720: 'party',
#  721: 'Im',
#  722: 'waiter',
#  723: 'order',
#  724: 'Italian',
#  725: 'onion',
#  726: 'thinking',
#  727: 'absolutley',
#  728: 'plethora',
#  729: 'forgetting',
#  730: 'myself',
#  731: 'But',
#  732: 'cost',
#  733: 'mesquite',
#  734: 'pay',
#  735: 'tartare',
#  736: 'cake',
#  737: 'Brushfire',
#  738: 'salt',
#  739: 'hits',
#  740: 'needs',
#  741: 'missed',
#  742: 'biggest',
#  743: 'especially',
#  744: 'article',
#  745: 'leaves',
#  746: 'Nobu',
#  747: 'honor',
#  748: 'evening',
#  749: 'RUDE',
#  750: 'shower',
#  751: 'public',
#  752: 'Fridays',
#  753: 'reasonable',
#  754: '...',
#  755: 'final',
#  756: 'walls',
#  757: 'skimp',
#  758: 'black',
#  759: 'says',
#  760: 'Thumbs',
#  761: 'flavorless',
#  762: 'shopping',
#  763: 'metro',
#  764: 'realized',
#  765: 'trimmed',
#  766: 'patron',
#  767: 'Plus',
#  768: 'chefs',
#  769: 'caught',
#  770: 'across',
#  771: 'claimed',
#  772: 'refused',
#  773: 'solidify',
#  774: 'yourself',
#  775: 'Delight',
#  776: 'Appetite',
#  777: 'NO',
#  778: 'At',
#  779: 'Mom',
#  780: 'Eggplant',
#  781: 'dusted',
#  782: 'as',
#  783: 'HAVE',
#  784: 'seriously',
#  785: 'dirty-',
#  786: 'show',
#  787: 'cramming',
#  788: 'side',
#  789: 'then',
#  790: 'genuinely',
#  791: 'wagyu',
#  792: 'heads',
#  793: 'daily',
#  794: 'pancakes',
#  795: 'requested',
#  796: 'joy',
#  797: 'pumpkin',
#  798: 'AGAIN',
#  799: 'dude',
#  800: 'an',
#  801: 'watered',
#  802: 'NEVER',
#  803: 'reasonably',
#  804: 'avoided',
#  805: 'going',
#  806: 'light',
#  807: 'here',
#  808: 'MANAGEMENT',
#  809: 'expert/connisseur',
#  810: 'used',
#  811: 'portion',
#  812: 'lukewarm',
#  813: 'beyond',
#  814: 'vegan/veggie',
#  815: 'him',
#  816: 'walked',
#  817: 'professional',
#  818: 'sliced',
#  819: 'OK',
#  820: 'They',
#  821: 'without',
#  822: 'unhealthy',
#  823: 'raspberry',
#  824: 'giving',
#  825: 'trippy',
#  826: 'zero',
#  827: 'chocolate',
#  828: 'reservation',
#  829: 'table',
#  830: 'occasions',
#  831: 'Baseball',
#  832: 'IT',
#  833: 'Buldogis',
#  834: 'mistake',
#  835: 'poured',
#  836: 'looked',
#  837: 'proclaimed',
#  838: 'Pros',
#  839: 'sucked',
#  840: 'Plater',
#  841: 'date',
#  842: 'Probably',
#  843: 'mains',
#  844: 'finally',
#  845: 'gratuity',
#  846: 'attentive',
#  847: 'sugar',
#  848: 'contained',
#  849: 'foods',
#  850: 'Strip',
#  851: 'Sprouts',
#  852: 'trying',
#  853: 'easily',
#  854: 'would',
#  855: 'shoots',
#  856: '90',
#  857: 'TOTAL',
#  858: 'ambiance',
#  859: 'are',
#  860: 'treated',
#  861: 'First',
#  862: 'new',
#  863: 'rare',
#  864: 'fails',
#  865: 'years',
#  866: 'RI',
#  867: 'truly',
#  868: 'received',
#  869: 'unprofessional',
#  870: 'so',
#  871: 'bunch',
#  872: 'groups',
#  873: 'Both',
#  874: 'beauty',
#  875: 'bite',
#  876: 'trip',
#  877: 'larger',
#  878: 'beateous',
#  879: 'red',
#  880: 'Mandalay',
#  881: 'rest',
#  882: 'spring',
#  883: 'Jamaican',
#  884: 'wants',
#  885: 'touched',
#  886: 'extensive',
#  887: 'Soups',
#  888: 'outdoor',
#  889: 'reduction',
#  890: 'Hawaiian',
#  891: 'Casino',
#  892: 'short',
#  893: 'book',
#  894: 'Server',
#  895: 'completely',
#  896: 'Went',
#  897: 'court',
#  898: 'mouth',
#  899: 'cashier',
#  900: 'fresh',
#  901: 'word',
#  902: 'juice',
#  903: 'person',
#  904: 'work',
#  905: 'law',
#  906: 'play',
#  907: 'Shop',
#  908: 'mouthful',
#  909: 'LEGIT',
#  910: 'Now',
#  911: 'rate',
#  912: 'Spend',
#  913: 'grease',
#  914: 'overhaul',
#  915: 'tolerance',
#  916: 'hereas',
#  917: 'Paradise',
#  918: 'devine',
#  919: 'Hiro',
#  920: 'been-stepped-in-and-tracked-everywhere',
#  921: 'saffron',
#  922: 'of',
#  923: 'opened',
#  924: '1/2',
#  925: 'sorely',
#  926: 'suck',
#  927: 'real',
#  928: 'maybe',
#  929: 'finger',
#  930: 'ground',
#  931: 'banana',
#  932: 'is',
#  933: 'pine',
#  934: 'somewhat',
#  935: 'gyros',
#  936: 'works',
#  937: 'Thai',
#  938: 'hostess',
#  939: 'pastas',
#  940: 'quickly',
#  941: 'Mushroom',
#  942: 'make',
#  943: 'chains',
#  944: 'always',
#  945: 'besides',
#  946: 'thumbs',
#  947: 'modern',
#  948: 'dont',
#  949: 'Gordon',
#  950: 'if',
#  951: 'charming',
#  952: 'Sat',
#  953: 'crisp',
#  954: 'tell',
#  955: 'station',
#  956: 'Buffet',
#  957: 'find',
#  958: 'live',
#  959: 'wasting',
#  960: 'delicate',
#  961: 'cooking',
#  962: 'Hands',
#  963: 'meals',
#  964: 'tea',
#  965: 'Highly',
#  966: 'replenished',
#  967: 'drenched',
#  968: 'but',
#  969: 'stars',
#  970: 'bone',
#  971: 'refill',
#  972: 'refried',
#  973: 'opportunity',
#  974: 'rib',
#  975: 'beautiful',
#  976: 'Tucson',
#  977: 'guess',
#  978: 'Wienerschnitzel',
#  979: 'review',
#  980: 'peach',
#  981: 'peanuts',
#  982: 'serves',
#  983: 'BITCHES',
#  984: 'undercooked',
#  985: 'fell',
#  986: 'inexpensive',
#  987: 'its',
#  988: 'decision',
#  989: 'busy',
#  990: 'disagree',
#  991: 'giant',
#  992: 'garden',
#  993: "ya'all",
#  994: 'gem',
#  995: 'FREEZING',
#  996: 'descriptions',
#  997: 'Joey',
#  998: 'crêpe',
#  999: 'Elk',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
