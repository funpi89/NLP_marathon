# %%
# !python --version
# Out:
# Python 3.7.9

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n
        index2word[n] = word
        n += 1

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['弗格森', '朱', '溫格', '亞特拉斯賽', '埃姆雷', '安迪爾森', '里皮', '余承東', '游玄德', 'J羅', '萊萬特', '小詹皇', 'P60八核讓', '璞麗', '殺里', '盧克肖', '查理芒格', '斐濟', '馬內', '衛報', '切沃', '天貓', '卡帥', '聯發科', '世界杯', '克羅托內 ', '新游', '龔方雄', '喬丹', '浦發', '奧拉朱旺遠', '張本智和', '陶華碧', '詹', '納米 華', '郎平', '慧商', '卡拉斯科', '微眾', '伊藤美誠', '娜迦王海伯倫', '賈躍亭', '德安東尼', '蘇群', '武當', '奧恰洛夫', '阿迪薩亞', '東決', '朱嘯虎', '紫鑫', '勇士隊', '約翰塞納', '海富通', '郭春林', '曼聯', '恆生', '梵', '億航', '·龜茲', '何享健', '凱爾特', '湯米', '伯克希爾', '馬夏爾', '李謹詺', '塔特姆', '泰倫', '伊亞', '高傭', '科爾', '唐汪鎮', '馬化騰', '何雯娜', '大豐', '內馬爾', '中金', '瓦基弗', '泰拳王西', '李白界', '林員', '安利', '圍甲', '騰訊', '·瞻', '石川佳純', 'Dota2', '景泰石', '富力', '斯諾克', '大美', '阿里雲', '大神', '四阿哥', '丁寧', '丘誠', '加威廉', '皮爾洛', '迪士尼', '馬克思', '王楚欽']
# =======================
# VC : ['碰到', '靠近', '獨造', '防治', '扒出', '豪取', '春栽', '命懸', '打死', '直播', '摘', '調侃', '兌換', '掛', '屠殺', '毀滅', '關掉', '揭密', '收穫', '控制', '放棄', '採摘', '脫離', '攻略', '丟', '娶', '集訓', '添脫', '踐行', '駕馭', '觀賞', '治療', '完虐', '接受', '打不過', '釋放', '吃好', '喜迎', '要', '鋪開', '廢', '看待', '提升', '嘲諷', '傳用', '領取', '起到', '收', '虛擬', '打', '取得', '列', '教會', '清理', '救贖', '約', '引入', '毀掉', '拋投', '追', '利用', '反擊', '刷到', '吸', '賞', '參觀', '回購', '採用', '穩住', '指責', '單挑', '大戰', '吹', '添加', '纏', '欺騙', '整入', '生產', '防控', '雷劈', '養成', '測', '提高', '抵押', '搬進', '取捨', '拼', '移', '邀請', '採訪', '玩', '迎立', '割', '暢玩', '產', '分銷', '懵逼', '刷爆', '訓練', '作']
# =======================
# Na : ['獎金', '生物炭', '紅綠燈', '銀', '保千里', '政企', '閃魔戰', '笑容', '觀眾', '里皮', '節奏', '移速', '指數', '老闆', '時節', '語言', '定制商', '大獎', '運動員', '收穫', '諾手', '意甲', '激情', '婦聯', '重點', '缺口', '期間', '風潮', '秘籍', '義務教育', '紅土', '醫藥', '收入', '夕陽', '部門', '熱議', '櫻桃', '用途', '自行車', '舉措', '油', '車釐子', '心骨', '柿苗期', '空地', '味', '組合', '操盤手', '廢品', '工匠', '藥明', '源音箱', '預言家', '救主', '果苗', '魔', '餘額', '道題', '魔王', '臉', '大胃王', '希望', '百香', '電商', '人氣', '大戰', '高層', '好友', '能力', '圖文', '進展', '特徵', '王朝', '英雄', '序', '悅花', '大人參', '服務員', '品種', '油菜花', '溶洞', '設計', '路集', '成年人', '麻辣魚', '空間', '家家戶戶種', '龍果', '音量', '醫保', '離子', '竹絲', '類股', '種松', '疾病', '藍花楹', '厚望', '失誤', '課', '矮壯素能']
# =======================
# COLONCATEGORY : ['：', ':']
# =======================
# Nc : ['聯合村', '平邑', '老家', '世界', '家', '新疆', '江蘇', '河南', '實驗室', '葉縣', '東北', '拉薩', '茶館', '山東', '萊茵河', '農家', '新田', '中行', '撫遠', '人間', '耿店村', '墾丁', '閬', '里貝里', '南粵', '市', '山海', '高空', '子公司', '鹽城', '麥當勞', '馬德里', '新化縣', '國內', '中心', '廣東', '科', '農場', '小學', '亞馬遜', '洋溪鎮', '亞洲', '寶雞', '黃鶴樓', '雜貨鋪', '荒野', '湖南省', '營口', '官總', '紅河谷', '鮁魚圈區', '火鍋店', '寶安', '南山', '天津', '西安比', '濟南', '農資店', '三宜', '外地', '延邊', '旗下', '社區', '石家莊', '嵐山', '中國', '產茶縣', '梅縣', '迪拜', '南寧', '國', '莊浪', '吉林', '朝邑鎮', '淡水', '柯橋', '河北', '北控', '南極', '城鎮', '酒館', '綿竹', '廣安', '窮游', '天際', '崗位', '斯里蘭卡', '中棉', '侗寨', '石鼓園', '霞飛', '蕩漾湖', '上海', '牛排館', '宜昌', '網站', '唐人街', '山村', '滕州', '內內']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['分段', '再見', '解惑', '應對', '罰款', '鋪平', '效力', '抓來', '代打', '充氣', '解體', '執教', '定位', '解密', '一網打盡', '拍照', '站台', '分組', '護航', '相比', '退貨', '導航', '加油', '提前', '加工', '騙錢', '收回來', '充飢', '領銜', '復仇', '通話', '助威', '解圍', '加起來', '融資', '計算出來', '退款', '退改', '加持', '扣分', '入賬', '加冕', '罵屌絲', '上架', '開戰', '分紅', '鍍金']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['時刻', '少', '一一', '得', '均', '總是', '反', '及時', '來', '從', '仍', '必然', '隨', '一路', '急劇', '會不會', '並', '再次', '竟然', '亂', '不得', '頻', '好像', '白', '難道', '盡快', '就', '很少', '天南地北', '大力', '立即', '首先', '隨地', '只有', '分別', '帶頭', '專職', '不得不', '不再', '只得', '恆', '可能', '同', '應', '率先', '怎樣', '能否', '好在', '要', '變相', '不要', '交互', '皆', '老是', '吃起來', '聯合', '終', '絕對', '恐怕', '一頭', '略', '不能', '又', '迫不及待', '從來', '屢屢', '現', '多', '一起', '大都', '自', '玩絕', '預先', '屢', '為什麼', '剛剛', '超級', '結伴', '別', '再度', '總', '悄悄', '連', '都', '有沒有', '可', '從未', '永', '隨時', '還是', '在', '或許', '到處', '曾經', '未必', '本', '怎能', '新', '一般', '真']
# =======================
# P : ['往', '把', '當', '遭', '針對', '對', '等', '與', '繼', '向', '比', '從', '按', '隨', '幫', '靠', '被', '因', '如', '除', '自', '用', '為了', '像', '至', '比如', '慘遭', '憑', '自從', '臨', '和', '關於', '受', '就', '到', '趁', '為', '在', '以', '除了', '待', '離', '隨了', '直至', '跟', '距離', '根據', '將', '於', '給', '趁著']
# =======================
# VG : ['稱作', '叫做', '當', '排', '美成', '猶如', '作為', '形成', '戰成', '彷彿', '疑似', '非', '似', '改造成', '投票成', '化', '譽為', '評選', '升任', '如', '充當', '酷似', '屬於', '建成', '叫', '像', '當上', '排名', '類似', '集成', '排行', '居', '變成', '等於', '並列', '為', '應聘', '姓', '賣成', '封號', '當成', '合成', '稱得上', '算是', '做成', '理解為', '稱', '做', '成為', '算', '名叫', '堪稱', '竟是', '當作', '誤認成', '屈居', '稱為', '變', '成']
# =======================
# Neu : ['六', '5.7', '7', '300萬', '25', '三', '(00926)', '2400', '四', '6', '第二', '十萬', '50多', '40', '85', '0', '98', '萬', '5050', '十五萬', '五一', '千億', '20萬一', '第七', '010', '175', '2018-05-06 ', '2599', '3:2', '11', '42', '一500', '2萬', '15.60', '1.3萬', '14', '3:0', '3-0', '120', '2.5', '3:1', '600', '46萬', '第36', '第一！', '11.59億', '第四十四', '零', '700', '11億', '5.6千三', '9-0', '30', '24', '十六', '數千萬', '835', '5.5', '0:0', '3100', '20億', '三千億', '35萬', '十多萬', '萬億', '3', '100多', '318', '幾', '17億', '幾百', '8萬', '1688', '1000', '0-1', '第1', '五', '150', '二', '36萬', '30000億', '1300萬', '30萬', '2018', '2:3', '1299', '第33', '5萬', '2018.', '第九', '120萬', '200', '23萬一', '二〇三', '0-', '千', '一萬', '17', '4萬多', '500']
# =======================
# Nf : ['場', '對', '類', '座', '家', '名', '刻', '掛', '戶', '棵', '週', '檔', '款', '套', '日', '句', '節', '年', '噸', '招', '處', '胎', '級', '把', '筆', '關', '番', '輛', '部', '行', '英吋', '方', '周', '票', '袋', '項', '分', '條', '門', '片', '隊', '塊', '美元', '本', '公里', '局', '層', '畝', '槍', '個', '輪', '班', '斤', '鍋', '晚', '所', '頭', '點', '歲', '件', '則', '港元', '台', '盤', '路', '分鐘', '批', '群', '度', '支', '只', '串', '元', '屆', '色', '號', '期', '秒', '碗', '頁', '股', '天', '篇', '道', '遍', 'K', '口', '株', '米', '些', '位', '隻', '步', '張', '回', '樣', '次', '頓', '種', '毛']
# =======================
# VJ : ['羨慕', '遭遇', '認識', '維持', '虧損', '平', '享受', '錯失', '得', '吃上', '翻倍', '共享', '擁有', '獲', '替代', '靠', '出於', '值', '懷念', '限', '不如', '衝', '認', '關注', '遺傳', '逾', '服', '受', '無', '忽視', '懼怕', '惜', '耗', '缺少', '曬', '看不過去', '達', '喪失', '煥發', '分享', '共有', '養有', '佔', '錯過', '順應', '自有', '恪守', '熱心', '蘊藏', '含有', '大勝', '贏下', '缺', '不理', '僅次於', '輸掉', '近', '充', '領略', '超過', '要價', '看懂', '持有', '失', '失去', '經歷', '出', '贊同', '高達', '忘懷', '爆發', '來自', '沒', '歸', '適應', '領跑', '減持', '入圍', '優於', '沒有', '沈迷', '冷落', '強過', '展望', '不敵', '納入', '入選', '忽略', '嫌棄', '贏得', '連接', '為', '減', '發生', '心疼', '獲得', '震撼到', '負於', '看好', '恭喜']
# =======================
# VD : ['速遞', '予', '供應', '輸', '支付', '發', '欠', '配', '售', '補貼', '郵給', '賣', '傳', '付', '送', '補繳', '還', '收費', '白送', '貸', '發放', '發給', '貸款', '坑', '借', '分', '轉讓', '清繳', '拒賠', '贏', '搶', '輸給', '寄予', '提供', '借貸', '給予', '交付', '給', '禁售']
# =======================
# Dfa : ['還要', '十分', '比較', '極', '遠遠', '太', '遠', '越來越', '多', '好', '同樣', '較', '很', '這麼', '還', '更', '最', '過', '有些', '非常', '不大', '有點', '頗', '更為', '超', '如此', '過於']
# =======================
# VH : ['決裂', '復活', '活躍', '適合', '不得了', '特殊', '不行', '相應', '恍然大悟', '爭相鬥艷', '靦腆', '芳香', '沒用', '另類', '小小', '分夠', '好用', '呆滯', '漲停', '現代', '飽', '交流', '巨大', '摸不透', '惡化', '單身', '竊喜', '熟', '有毒', '深', '可口', '小', '傳統', '算數', '平平無奇', '有望', '倒閉', '爆炸', '稱霸絕', '值得', '丟臉', '迷路', '零零', '激烈', '完美', '映美', '退市', '轉旺', '過多', '出色', '近', '驚恐', '快樂', '有用', '古老', '好禮', '密集', '優越', '優秀', '相關', '狂野', '好看', '皆大歡喜', '受益匪淺', '濕潤', '大漲', '隨意', '上漲', '冒雨', '好玩', '有名', '吃香', '無憂', '亂真', '凝重', '多樣', '遠', '一樣', '高效', '靠譜', '殫精竭慮', '開通', '眾多', '榮幸', '生存', '重大', '歡樂', '獨特', '有意思', '這麼', '強硬', '慘敗', '崩盤', '甜蜜', '徹底', '無效', '合作', '天生', '魔幻', '看呆']
# =======================
# Cbb : ['還不如', '假如', '跟著', '只要', '就算', '因', '不然', '並', '不僅', '不管', '不如', '並且', '若', '但', '連', '另外', '既然', '只有', '既', '反而', '否則', '而', '雖然', '要是', '即使', '如果', '因為', '不過', '但是', '可是', '縱使', '而是']
# =======================
# Nd : ['週末', '以前', '六', '7日', '3月', '採摘節', '週二', '季', '明年', '秋季', '短期', '夏天', '5號', '不久', '長期', '隔年', '晚間', '1點', '月季', '23日', '夏', '現代', '春天', '06日', '早晨', '半夜', '正月', '當前', '九月', '一大早', '永久', '後期', '一會', '今天', '5月', '米節', '過去', '2019年', '1日', '15日', '夏季', '明晚', '狗年', '明日', '5.7日', '5日', '當年', '-5', '31號', '夏窗', '2018', '4月', '周', '四月', '何時', '90年', '05月', '旅遊節', '2005年', '4日', '如今', '近日', '季度', '未來', '6日', '一日', '2020年', '當時', '2018年', '8月', '春', '下旬', '明', '一下', '荒古', '初夏', '12日', '五月份', '那時', '今日', '2017年', '熱天', '相親節', '文化節', '10點', '夜', '多久', '2018年度', '花季', '30號', '中旬', '秋', '昔日', '中期', '夏日', '最後', '19年', '昨天', '七月份', '大中']
# =======================
# VA : ['吸粉', '回家', '上場', '產仔', '划溝', '聊天', '離隊', '報關', '溢出', '狩獵', '大笑', '現身', '盤旋', '偷鯤', '搶七', '表態', '轉會', '放水', '壓哨', '會師', '扶貧', '幹什麼', '扶牆', '打球', '關機', '度假', '巡禮', '相克', '轉賬', '騎行', '飆車', '回來', '申遺', '出門', '看盤', '除權', '捲土重來', '上門', '退', '求生', '坐穩', '回落', '革命', '遠行', '出場', '徜徉', '起飛', '正名', '爭吵', '運營', '下雪', '跑跑', '懷孕', '反彈', '付錢', '投訴', '攻堅', '下降', '發貨', '種地', '續約', '出台', '加密', '聯通', '喧囂', '滑雪', '上線', '進城', '遊玩', '觀戰', '助攻', '排兵', '放飛', '探案', '違規', '抽籤', '閉嘴', '鬥智', '聚焦', '走起', '打卡', '存在', '反轉', '騎車', '過閘', '奔', '來', '賺錢', '大小便', '消失', '步行', '爬山', '拍案叫絕', '播種', '醫人', '進去', '旅遊', '毀號', '換人', '走']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['前', '同', '該', '頭', '貴', '某', '後', '每', '下', '何', '上', '另', '近', '各', '本', '首']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['個', '過', '了', '著', '起來']
# =======================
# Nep : ['此', '啥', '什麼', '其', '其中', '那', '哪', '這']
# =======================
# Caa : ['或', 'VS', '到', '及', '暨', '或者', '還是', '與', '跟', '比', '至', '又', '或是', '和']
# =======================
# VCL : ['穿越', '往', '穿過', '走下', '升至', '穿透', '上', '橫掃', '前來', '重回', '路過', '存進', '進', '留在', '跌出', '盤踞', '跌至', '玩遍', '走訪', '直達', '進入', '赴', '走進', '到', '重返', '走過', '過', '登陸', '來到', '在', '入', '出發到', '退出', '去', '回', '出', '住', '栽進', '暗渡', '蒞臨', '遊覽', '前往', '回到', '抵達', '深入', '回歸', '到達', '用於', '走到', '度過', '遠離']
# =======================
# Neqa : ['無數', '一切', '一半', '四成', '遍', '滴滴', '這些', '不少', '多', '6%', '80%', '半', '1/4', '全', '多點', '一點', '句句', '大量', '任何', '9.89%', '一處處', '個個', '步步', '這麼多', '很多', '90%', '大多數', '許多', '所有', '多少', '100%', '10%', '有些', '其他', '20%', '大多', '其它', '1%', '15%', '一些', '8%', '哪些', '那些', '三分之一', '有的', '更多', '30%', '部分', '0.8%', '百分之八十', '12%', '67%', '41.8%']
# =======================
# Nh : ['我', '個人', '本人', '自我', '俺們', '私人', '他', '父子倆', '一方', '它', '各自', '對方', '你', '她們', '大家', '您', '人家', '自身', '她', '小眾', '他們', '雙方', '別人', '誰', '它們', '自己', '你們', '我們', '屌絲', '各位']
# =======================
# FW : ['RNG', 'FF ', 'i7', 'MSCI', '―', 'h', 'dnf', 'Guru', 'Fullestop', 'VR ', 'eStarPro vs WF.D', 'KV', 'J', 'l ', 'OMG', 'ipad', 'IP', ' 2017', 'CDR', 'CP', 'max2', 'GoogleI/O2018', 'CBA', 'One', 'OB', 'LOL', 'shou', '4AM', 'ios', 'qq', ' vs 利物浦', 'ABCC', 'NPC', 'DASH', 'IG', 'lol', 'e', '丨', 'vs', 'Rank', '｜', 'QGhappy', 'CFO', ' CCR', 'iPhone X', '-6', 'A', 'BCH', 'D', 'cba', '│', 'Soloking', 'iPad', 'S11', '：BTC', 'QG', 'mAh+', 'DNF ', 'adc', 'PK', 'PGM 0-1 SUP', 'Mc', 'Kakao', 'X', '9A91', 'AD', 'Nvidia', '+4', 'steam', 'wifi', 'CCR', 'W', 'IOS', 'bad boy', 'AIC', 'KBM', 'SUP', 'OV', 'iPhone7', 'TPP', 'Ghappy', '4H', 'N7', 'Pro', 'CF', 'FW', '+', 'Day', 'G3', '<', '2W', '>', 'T+0', '~', 'UI', '5A', 'King James', ' MDL', 'eStar', 'numb']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['講', '提醒', '禁止', '呼籲', '公佈', '知詢', '查找', '見到', '想到', '警惕', '看清楚', '安排', '深思', '判罰', '想', '估值', '算', '預定', '識別', '幻想', '判斷', '說明', '要', '准', '發佈', '公示', '認為', '宣佈', '報道', '抱怨', '做到', '預期', '防止', '證', '假設', '想要', '回顧', '介紹', '樂見', '限制', '提到', '暗示', '訴說', '預測', '探索', '聊', '探討', '盛贊', '感嘆', '查', '判定', '公告', '問', '看到', '發誓', '講解', '說', '確認', '研究', '想起', '揭曉', '傳聞', '精准', '提起', '廣播', '商量', '提', '披露', '自嘲', '管', '發現', '鑒定', '呼', '以為', '承諾', '爆料', '稱', '考慮', '談', '申卡', '查看', '聯想', '允許', '預告', '聽', '形容', '賭約', '預計', '公認', '見證', '示範', '預防', '避免', '聽到', '猜', '調研', '告訴', '想好', '看出', '慶祝']
# =======================
# DE : ['的', '得', '之', '地']
# =======================
# VHC : ['破', '滿足', '優化', '變動', '強化', '還原', '感動', '降低', '規模化', '陷', '結束', '公開', '震驚', '可憐', '智能化', '加快', '現代化', '增長', '下來', '縮小', '豐富', '穩定', '溫暖', '普及', '傷', '淡化', '開', '凍', '國際化', '愁死', '平衡', '麻煩', '愁壞', '團結', '告破', '擴張', '煩', '繁榮', '壞', '肥', '暫停', '增加', '辛苦', '增 ', '增強', '機構化', '冷卻', '停', '產生', '恢復', '斷', '熱', '減少']
# =======================
# Ng : ['前', '之外', '上', '來', '以來', '以後', '起', '初', '以下', '裡', '之前', '之後', '般', '外', '中', '之內', '後', '下', '之間', '以外', '而言', '內', '左右', '時', '之中', '之下', '以上', '之上', '間', '為止', '底']
# =======================
# VK : ['需', '感覺到', '奇怪', '願意', '願', '盼', '感覺', '依賴', '知', '不忘', '信', '面臨', '意想不到', '懂', '覺', '怕', '期待', '意外', '需要', '肯定', '感謝', '忘記', '瞭解', '喜歡', '知道', '不滿', '害怕', '感受', '所謂', '注意', '意味', '希望', '擔心', '恐', '介意', '忘', '指望', '流傳', '同意', '欲', '堅持', '遺憾', '放心', '曲解', '恨', '顯示', '懂得', '明白', '理解', '確定', '抱歉', '討厭', '小心', '覺得', '有利於', '回憶', '懷疑', '遇', '想見']
# =======================
# Ncd : ['上', '北', '哪下', '哪裡', '上面', '哪', '東部', '兩旁', '底部', '東方', '方', '上方', '以下', '裡', '東西部', '旁邊', '外', '中', '前沿', '那邊', '當中', '哪兒', '下', '畔', '西', '那裡', '中間', '一帶', '邊', '內', '裡面', '中部', '末端', '西部', '間', '對面', '這裡', '東', '外面']
# =======================
# A : ['原', '地下', '小本', '上上', '二手', '非', '寶有', '基層', '綜合', '高度', '獨門', '優質', '中西', '業餘', '長途', '國產', '超級', '前置', '現行', '中', '眾', '頭號', '單', '重磅', '多餘', '同一', '真正', '大幅度', '總', '常務', '歐式', '獨家', '乒乓', '同等', '碧藍', '唯一', '新一代', '火紅', '額外', '新興', '彩色', '基礎', '麻辣', '一般', '必備', '超', '雙', '共同', '現役', '野生', '後置', '最佳', '主', '獨角']
# =======================
# V_2 : ['有']
# =======================
# VL : ['使', '開始', '持續', '令', '敢', '用來', '讓', '甘願', '後悔', '便利', '習慣', '致', '使得', '肯', '趨於', '喜好', '愛', '故意', '導致', '不惜', '愛好', '能']
# =======================
# T : ['哦', '哪', '矣', '的', '了', '啊', '咯', '嗎', '來', '吧', '啦', '麼', '嘛', '去', '呢']
# =======================
# VI : ['驚艷', '傾心', '著稱', '專用', '取勝']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['哦', '瑪法里奧']
# =======================
# Dk : ['結果', '反過來', '外傳', '據說', '想不到', '那麼', '據聞', '那']
# =======================
# VF : ['停止', '擬', '告誡', '策劃', '圖', '打算', '拒絕', '勸說', '逼', '叫', '試試', '判', '邀', '準備', '率領', '助', '勸住', '催', '止住', '請', '繼續', '鼓勵', '帶領', '申請', '推選', '拒', '要求', '試']
# =======================
# Da : ['約', '正好', '才', '唯獨', '共', '不下', '足足', '幾近', '僅', '將近', '光', '只', '近', '幾乎', '最多']
# =======================
# PARENTHESISCATEGORY : ['」', '》', '《', '（', '「', '(', '）']
# =======================
# Nv : ['防治', '組合', '體驗', '疊加', '供電', '絕殺', '航海', '增發', '輔助', '批發', '射擊', '分銷', '護髮', '崩潰', '開發', '工作', '思考', '灌籃', '兼職', '推薦', '度假', '代理', '買單', '管理', '錄制', '創業', '旅遊', '判罰', '經歷', '燃燒', '翻譯', '私募', '登山', '銷售', '問', '關聯', '配置', '惡搞', '生產', '營銷', '遊樂', '抗戰', '解救', '訴訟', '研究', '回歸']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['推進', '蒸發', '上演', '移動', '集合', '動']
# =======================
# Dfb : ['極了', '些', '一點']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['多', '半', '幾', '以上']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    len_bow1 = np.sqrt(np.sum(np.square(bow1)))
    len_bow2 = np.sqrt(np.sum(np.square(bow2)))
    similarity = np.sum(bow1*bow2) / (len_bow1 * len_bow2)
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
